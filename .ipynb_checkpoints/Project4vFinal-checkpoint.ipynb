# %% [markdown]
# <h1>Regression Analysis</h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import calendar
import numpy as np
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestRegressor
#import pydotplus
from sklearn import tree
import collections
#import graphviz
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,accuracy_score
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import itertools
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import Ridge,Lasso,ElasticNet
from sklearn.model_selection import GridSearchCV

# %%
dataset = pd.read_csv('network_backup_dataset.csv')
dataset.head()
# Out:
#    Week # Day of Week  Backup Start Time - Hour of Day Work-Flow-ID File Name  \
# 0       1      Monday                                1  work_flow_0    File_0
# 1       1      Monday                                1  work_flow_2   File_12
# 2       1      Monday                                1  work_flow_2   File_13
# 3       1      Monday                                1  work_flow_2   File_14
# 4       1      Monday                                1  work_flow_2   File_16
#
#    Size of Backup (GB)  Backup Time (hour)
# 0                  0.0                   0
# 1                  0.0                   0
# 2                  0.0                   0
# 3                  0.0                   0
# 4                  0.0                   0

# %% [markdown]
# <h2>Question 1 - a, b</h2>

# %%
def encode_day_names(days):
    day_to_num = dict(zip(list(calendar.day_name), range(1, 8)))
    return [day_to_num[day] for day in days]

# %%
def plot_dataset(df):
    fig, ax = plt.subplots()
    labels = []
    for wid, wgrp in df.groupby('Work-Flow-ID'):
        ax = wgrp.groupby('Day #').sum().plot(
                ax = ax,
                kind = 'line',
                y = 'Size of Backup (GB)',
            )
        labels.append(wid)

        lines, _ = ax.get_legend_handles_labels()

        plt.xlabel('Day number')
        plt.ylabel('Backup size (GB)')

        ax.legend(lines, labels, bbox_to_anchor=(1, 1))
        ax.set_title('Backup size variation')
    plt.show()

# %%
dataset['Day #'] = (dataset['Week #'] - 1) * 7 + encode_day_names(dataset['Day of Week'])

# %%
twenty = dataset.loc[dataset['Day #'] >= 21]
twenty = twenty.loc[twenty['Day #'] <= 40]
plot_dataset(twenty)

# %%
first105 = dataset.loc[dataset['Day #'] <= 105]
plot_dataset(first105)

# %% [markdown]
# <h2>Question 2 - a</h2>

# %%
df = dataset.replace({'Day of Week': {'Monday': 1, 'Tuesday': 2, 'Wednesday': 3, 'Thursday': 4, 'Friday': 5,
                                  'Saturday': 6, 'Sunday': 7},
                  'Work-Flow-ID': {'work_flow_0': 0, 'work_flow_1': 1, 'work_flow_2': 2, 'work_flow_3': 3,
                                   'work_flow_4': 4},
                  'File Name': {'File_0': 0, 'File_1': 1, 'File_2': 2, 'File_3': 3, 'File_4': 4, 'File_5': 5,
                                'File_6': 6, 'File_7': 7, 'File_8': 8, 'File_9': 9, 'File_10': 10, 'File_11': 11,
                                'File_12': 12, 'File_13': 13, 'File_14': 14, 'File_15': 15, 'File_16': 16,
                                'File_17': 17, 'File_18': 18, 'File_19': 19, 'File_20': 20, 'File_21': 21,
                                'File_22': 22,
                                'File_23': 23, 'File_24': 24, 'File_25': 25, 'File_26': 26, 'File_27': 27,
                                'File_28': 28, 'File_29': 29, }})

# %%
df.head()
# Out:
#    Week #  Day of Week  Backup Start Time - Hour of Day  Work-Flow-ID  \
# 0       1            1                                1             0
# 1       1            1                                1             2
# 2       1            1                                1             2
# 3       1            1                                1             2
# 4       1            1                                1             2
#
#    File Name  Size of Backup (GB)  Backup Time (hour)
# 0          0                  0.0                   0
# 1         12                  0.0                   0
# 2         13                  0.0                   0
# 3         14                  0.0                   0
# 4         16                  0.0                   0

# %%
X = df[
    ['Week #', 'Day of Week', 'Backup Start Time - Hour of Day', 'Work-Flow-ID', 'File Name']].values
y = df['Size of Backup (GB)'].values

# %% [markdown]
# ### Part i

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=0)
linreg = LinearRegression()
linreg.fit(X_train, y_train)
print ("Coefficients:", linreg.coef_)
print ("Intercept:", linreg.intercept_)
y_predict = linreg.predict(X_test)
print("RMSE without cross validation:", np.sqrt(mean_squared_error(y_test, y_predict)))
# Out:
# Coefficients: [ -4.46137250e-05  -2.40527826e-03   1.38306408e-03  -4.14520552e-04
#    4.85929375e-04]
# Intercept: 0.049413880522
# RMSE without cross validation: 0.106503866998

# %%
def perform_10fold(X,y,regressor):
    kf = KFold(n_splits=10,shuffle=True, random_state=0)
    i = 1
    bestModel = None
    tr_e = 0
    ts_e = 0
    min_ts_e = 10
    for train_index, test_index in kf.split(X):
        print("Fold : ",i)
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        regressor.fit(X_train,y_train)
        train_preds = regressor.predict(X_train)
        test_preds = regressor.predict(X_test)
        test_error = mean_squared_error(y_test,test_preds)
        tr_e += mean_squared_error(y_train,train_preds)
        ts_e += test_error
        print("Training RMSE : ",np.sqrt(mean_squared_error(y_train,train_preds)))
        print("Test RMSE : ",np.sqrt(test_error))
        if(test_error<min_ts_e):
            min_ts_e = test_error
            bestModel = regressor
        i = i+1
    return np.sqrt(tr_e/10),np.sqrt(ts_e/10), bestModel

# %%
def plot_graph(x,y,xlabel,ylabel,title):
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.scatter(x, y, color='blue', lw=1, label=y,s=3)
    #plt.plot([y.min(), y.max()], [0,0], 'k--', lw=4)
    plt.show()

# %%
def plot_graph_time(y1,y2,y1label,y2label,ylabel,title):
    plt.title(title)
    plt.scatter(np.arange(y1.shape[0]), y1, color='blue', label=y1label,s=3)
    plt.scatter(np.arange(y1.shape[0]), y2, color='red', label=y2label,s=3)
    plt.xlabel('Time')
    plt.ylabel(ylabel)
    plt.legend(loc='upper left')
    plt.show()

# %%
regressor = LinearRegression()
avg_tr,avg_ts,bestModel = perform_10fold(X,y,regressor)
print("------------------------------")
print("Average Training RMSE : ",avg_tr)
print("Average Test RMSE : ",avg_ts)
# Out:
# Fold :  1
# Training RMSE :  0.103265021252
# Test RMSE :  0.106503866998
# Fold :  2
# Training RMSE :  0.103428926322
# Test RMSE :  0.105029409306
# Fold :  3
# Training RMSE :  0.101891490799
# Test RMSE :  0.117793845398
# Fold :  4
# Training RMSE :  0.104325747394
# Test RMSE :  0.0967244993663
# Fold :  5
# Training RMSE :  0.104118712604
# Test RMSE :  0.0987136373113
# Fold :  6
# Training RMSE :  0.104606731957
# Test RMSE :  0.0939770759809
# Fold :  7
# Training RMSE :  0.103710941139
# Test RMSE :  0.102543127434
# Fold :  8
# Training RMSE :  0.102680720217
# Test RMSE :  0.111465416023
# Fold :  9
# Training RMSE :  0.103622312889
# Test RMSE :  0.103306632317
# Fold :  10
# Training RMSE :  0.104198598987
# Test RMSE :  0.0979498611003
# ------------------------------
# Average Training RMSE :  0.103587856885
# Average Test RMSE :  0.103627896737

# %%
predicted = bestModel.predict(X)

# %%
plot_graph(y,predicted,"Actual","Fitted","Fitted vs Actual")
plot_graph_time(y,predicted,"Actual","Fitted","Actual and Fitted values","Actual and Fitted values over time")
plot_graph(predicted,y-predicted,"Fitted","Residual","Residual vs Fitted")
plot_graph_time(y-predicted,predicted,"Residual","Fitted","Residual and Fitted values","Residual and Fitted values over time")

# %% [markdown]
# ### Part ii

# %%
X = df[
    ['Week #', 'Day of Week', 'Backup Start Time - Hour of Day', 'Work-Flow-ID', 'File Name']].values
y = df['Size of Backup (GB)'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1,random_state = 0)
scaler = StandardScaler()
X_train_std = scaler.fit_transform(X_train)
X_test_std = scaler.transform(X_test)
linreg = LinearRegression()
linreg.fit(X_train_std, y_train)
print ("Coefficients:", linreg.coef_)
print ("Intercept:", linreg.intercept_)
y_predict = linreg.predict(X_test_std)
print("RMSE without cross validation:", np.sqrt(mean_squared_error(y_test, y_predict)))
# Out:
# Coefficients: [-0.00019274 -0.00479403  0.00944936 -0.00058665  0.00420832]
# Intercept: 0.0607646798087
# RMSE without cross validation: 0.106503866998
# C:\Users\shivu.soman\Anaconda3\lib\site-packages\sklearn\utils\validation.py:429: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, _DataConversionWarning)

# %%
def perform_10fold_std(X,y,regressor):
    kf = KFold(n_splits=10, shuffle=True, random_state = 0)
    i = 1
    bestModel = None
    tr_e = 0
    ts_e = 0
    min_ts_e = 10
    for train_index, test_index in kf.split(X):
        print("Fold : ",i)
        scaler = StandardScaler()
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        X_train_std = scaler.fit_transform(X_train)
        X_test_std = scaler.transform(X_test)
        regressor.fit(X_train_std,y_train)
        train_preds = regressor.predict(X_train_std)
        test_preds = regressor.predict(X_test_std)
        test_error = mean_squared_error(y_test,test_preds)
        tr_e += mean_squared_error(y_train,train_preds)
        ts_e += test_error
        print("Training RMSE : ",np.sqrt(mean_squared_error(y_train,train_preds)))
        print("Test RMSE : ",np.sqrt(test_error))
        if(test_error<min_ts_e):
            min_ts_e = test_error
            bestModel = regressor
        i = i+1
    return np.sqrt(tr_e/10),np.sqrt(ts_e/10), bestModel

# %%
regressor = LinearRegression()
avg_tr,avg_ts,bestModel = perform_10fold_std(X,y,regressor)
print("------------------------------")
print("Average Training RMSE : ",avg_tr)
print("Average Test RMSE : ",avg_ts)
# Out:
# Fold :  1
# Training RMSE :  0.103265021252
# Test RMSE :  0.106503866998
# Fold :  2
# Training RMSE :  0.103428926322
# Test RMSE :  0.105029409306
# Fold :  3
# Training RMSE :  0.101891490799
# Test RMSE :  0.117793845398
# Fold :  4
# Training RMSE :  0.104325747394
# Test RMSE :  0.0967244993663
# Fold :  5
# Training RMSE :  0.104118712604
# Test RMSE :  0.0987136373113
# Fold :  6
# Training RMSE :  0.104606731957
# Test RMSE :  0.0939770759809
# Fold :  7
# Training RMSE :  0.103710941139
# Test RMSE :  0.102543127434
# Fold :  8
# Training RMSE :  0.102680720217
# Test RMSE :  0.111465416023
# Fold :  9
# Training RMSE :  0.103622312889
# Test RMSE :  0.103306632317
# Fold :  10
# Training RMSE :  0.104198598987
# Test RMSE :  0.0979498611003
# ------------------------------
# Average Training RMSE :  0.103587856885
# Average Test RMSE :  0.103627896737
# C:\Users\shivu.soman\Anaconda3\lib\site-packages\sklearn\utils\validation.py:429: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, _DataConversionWarning)

# %%
X2 = scaler.fit_transform(X)
predicted = bestModel.predict(X2)
# Out:
# C:\Users\shivu.soman\Anaconda3\lib\site-packages\sklearn\utils\validation.py:429: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, _DataConversionWarning)

# %%
plot_graph(y,predicted,"Actual","Fitted","Fitted vs Actual")
plot_graph_time(y,predicted,"Actual","Fitted","Actual and Fitted values","Actual and Fitted values over time")
plot_graph(predicted,y-predicted,"Fitted","Residual","Residual vs Fitted")
plot_graph_time(y-predicted,predicted,"Residual","Fitted","Residual and Fitted values","Residual and Fitted values over time")

# %% [markdown]
# ### Part iii

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression,mutual_info_regression

# %%
X = df[
    ['Week #', 'Day of Week', 'Backup Start Time - Hour of Day', 'Work-Flow-ID', 'File Name']].values
y = df['Size of Backup (GB)'].values

# %%
selectbest = SelectKBest(f_regression,k=3)
X_f = selectbest.fit_transform(X, y)
selectbest.scores_
# Out:
# array([  8.45006257e-03,   3.88163798e+01,   1.50740934e+02,
#          2.61386654e+01,   2.53200943e+01])

# %% [markdown]
# #### Best features from f_regression = Day of the week, Backup time - hour of day, workflow id

# %%
selectbest2 = SelectKBest(mutual_info_regression,k=3)
X_mi = selectbest2.fit_transform(X, y)
selectbest2.scores_
# Out:
# /usr/local/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# array([  1.40542995e-04,   2.23909684e-01,   2.40665998e-01,
#          2.71181471e-01,   4.29231654e-01])

# %% [markdown]
# #### Best features from mutual_info_regression = Backup time - hour of day, workflow id, file name

# %%
regressor = LinearRegression()
avg_tr,avg_ts,bestModel_f = perform_10fold(X_f,y,regressor)
print("------------------------------")
print("Average Training RMSE : ",avg_tr)
print("Average Test RMSE : ",avg_ts)
# Out:
# Fold :  1
# Training RMSE :  0.103268532787
# Test RMSE :  0.106443895977
# Fold :  2
# Training RMSE :  0.103428949651
# Test RMSE :  0.105028305966
# Fold :  3
# Training RMSE :  0.101892287775
# Test RMSE :  0.117784174187
# Fold :  4
# Training RMSE :  0.104326006712
# Test RMSE :  0.0967192474504
# Fold :  5
# Training RMSE :  0.104119294498
# Test RMSE :  0.0987042824596
# Fold :  6
# Training RMSE :  0.104606957895
# Test RMSE :  0.0939729611901
# Fold :  7
# Training RMSE :  0.103711829314
# Test RMSE :  0.102521903924
# Fold :  8
# Training RMSE :  0.102682312458
# Test RMSE :  0.111434749983
# Fold :  9
# Training RMSE :  0.103623435712
# Test RMSE :  0.103290264859
# Fold :  10
# Training RMSE :  0.104198979884
# Test RMSE :  0.0979443610377
# ------------------------------
# Average Training RMSE :  0.103588792478
# Average Test RMSE :  0.103611218666

# %%
predicted = bestModel_f.predict(X_f)
plot_graph(y,predicted,"Actual","Fitted","Fitted vs Actual")
plot_graph_time(y,predicted,"Actual","Fitted","Actual and Fitted values","Actual and Fitted values over time")
plot_graph(predicted,y-predicted,"Fitted","Residual","Residual vs Fitted")
plot_graph_time(y-predicted,predicted,"Residual","Fitted","Residual and Fitted values","Residual and Fitted values over time")

# %%
regressor = LinearRegression()
avg_tr,avg_ts,bestModel_mi = perform_10fold(X_mi,y,regressor)
print("------------------------------")
print("Average Training RMSE : ",avg_tr)
print("Average Test RMSE : ",avg_ts)
# Out:
# Fold :  1
# Training RMSE :  0.103376399889
# Test RMSE :  0.106584984656
# Fold :  2
# Training RMSE :  0.103536556249
# Test RMSE :  0.105145558744
# Fold :  3
# Training RMSE :  0.101981401227
# Test RMSE :  0.118039036404
# Fold :  4
# Training RMSE :  0.104433193021
# Test RMSE :  0.0968436314645
# Fold :  5
# Training RMSE :  0.104235472414
# Test RMSE :  0.0987389195873
# Fold :  6
# Training RMSE :  0.104743818216
# Test RMSE :  0.0937778764769
# Fold :  7
# Training RMSE :  0.103791140701
# Test RMSE :  0.102876076128
# Fold :  8
# Training RMSE :  0.102796740173
# Test RMSE :  0.111511031697
# Fold :  9
# Training RMSE :  0.103726952957
# Test RMSE :  0.103446129396
# Fold :  10
# Training RMSE :  0.104320676685
# Test RMSE :  0.0979227774242
# ------------------------------
# Average Training RMSE :  0.103697228859
# Average Test RMSE :  0.103720626763

# %%
predicted = bestModel_mi.predict(X_mi)
plot_graph(y,predicted,"Actual","Fitted","Fitted vs Actual")
plot_graph_time(y,predicted,"Actual","Fitted","Actual and Fitted values","Actual and Fitted values over time")
plot_graph(predicted,y-predicted,"Fitted","Residual","Residual vs Fitted")
plot_graph_time(y-predicted,predicted,"Residual","Fitted","Residual and Fitted values","Residual and Fitted values over time")

# %% [markdown]
# ### Part iv

# %%
mask = []
for i in range(0,6):
    for j in itertools.combinations([0,1,2,3,4],i):
        mask_temp = [False,False,False,False,False]
        for index in j:
            mask_temp[index] = True
        mask.append(mask_temp)

# %%
#Without one hot encoding
tr_l = []
ts_l = []
print("Encoding : ",mask[0])
regressor = LinearRegression()
avg_tr,avg_ts,bestModel = perform_10fold(X,y,regressor)
tr_l.append(avg_tr)
ts_l.append(avg_ts)
print("Average Training RMSE : ",avg_tr)
print("Average Test RMSE : ",avg_ts)
predicted = bestModel.predict(X)
plot_graph_time(y,predicted,"Actual","Fitted","Actual and Fitted values","Actual and Fitted values over time")
plot_graph_time(y-predicted,predicted,"Residual","Fitted","Residual and Fitted values","Residual and Fitted values over time")
min_ts_e = avg_ts
bestModel_all = bestModel
best_mask = mask[0]
comb_num = 0
# Out:
# Encoding :  [False, False, False, False, False]
# Average Training RMSE :  0.103585393643
# Average Test RMSE :  0.103675847676

# %%
for i in range(1,32):
    print("##############################")
    print("Encoding : ",mask[i])
    encoder = OneHotEncoder(categorical_features = mask[i])
    X_encoded = encoder.fit_transform(X).toarray()
    regressor = LinearRegression()
    avg_tr,avg_ts,bestModel = perform_10fold(X_encoded,y,regressor)
    tr_l.append(avg_tr)
    ts_l.append(avg_ts)
    print("Average Training RMSE : ",avg_tr)
    print("Average Test RMSE : ",avg_ts)
    predicted = bestModel.predict(X_encoded)
    #plot_graph(y,predicted,"Actual","Fitted","Fitted vs Actual")
    plot_graph_time(y,predicted,"Actual","Fitted","Actual and Fitted values","Actual and Fitted values over time")
    #plot_graph(predicted,y-predicted,"Fitted","Residual","Residual vs Fitted")
    plot_graph_time(y-predicted,predicted,"Residual","Fitted","Residual and Fitted values","Residual and Fitted values over time")
    if(avg_ts<min_ts_e):
            min_ts_e = avg_ts
            min_tr_e = avg_tr
            bestModel_all = bestModel
            best_mask = mask[i]
            comb_num = i
print("--------------------------------")
print("Best Combination : ",best_mask)
print("Combination Number : ",comb_num)
print("Training RMSE : ",min_tr_e)
print("Test RMSE : ",min_ts_e)
print("Coefficients : ",bestModel_all.coef_)
print("Intercept : ",bestModel_all.intercept_)
# Out:
# ##############################
# Encoding :  [True, False, False, False, False]
# Average Training RMSE :  0.103580519421
# Average Test RMSE :  9557766082.57
# ##############################
# Encoding :  [False, True, False, False, False]
# Average Training RMSE :  0.10215359608
# Average Test RMSE :  0.102252844789
# ##############################
# Encoding :  [False, False, True, False, False]
# Average Training RMSE :  0.102361679221
# Average Test RMSE :  0.102468226473
# ##############################
# Encoding :  [False, False, False, True, False]
# Average Training RMSE :  0.0913395330666
# Average Test RMSE :  0.0914873383532
# ##############################
# Encoding :  [False, False, False, False, True]
# Average Training RMSE :  0.0913372558009
# Average Test RMSE :  0.0914982900118
# ##############################
# Encoding :  [True, True, False, False, False]
# Average Training RMSE :  0.10214938934
# Average Test RMSE :  15709588261.2
# ##############################
# Encoding :  [True, False, True, False, False]
# Average Training RMSE :  0.102355820029
# Average Test RMSE :  8295331501.07
# ##############################
# Encoding :  [True, False, False, True, False]
# Average Training RMSE :  0.091335173316
# Average Test RMSE :  15127793249.7
# ##############################
# Encoding :  [True, False, False, False, True]
# Average Training RMSE :  0.091333483742
# Average Test RMSE :  18634023184.5
# ##############################
# Encoding :  [False, True, True, False, False]
# Average Training RMSE :  0.100906502179
# Average Test RMSE :  0.10100640877
# ##############################
# Encoding :  [False, True, False, True, False]
# Average Training RMSE :  0.0897588362352
# Average Test RMSE :  0.089908467093
# ##############################
# Encoding :  [False, True, False, False, True]
# Average Training RMSE :  0.0897567709955
# Average Test RMSE :  0.0899115283978
# ##############################
# Encoding :  [False, False, True, True, False]
# Average Training RMSE :  0.0899509570374
# Average Test RMSE :  0.0901254490082
# ##############################
# Encoding :  [False, False, True, False, True]
# Average Training RMSE :  0.0899498382612
# Average Test RMSE :  0.0901242683863
# ##############################
# Encoding :  [False, False, False, True, True]
# Average Training RMSE :  0.0913384812944
# Average Test RMSE :  0.0914979826784
# ##############################
# Encoding :  [True, True, True, False, False]
# Average Training RMSE :  0.100938689838
# Average Test RMSE :  15971230702.0
# ##############################
# Encoding :  [True, True, False, True, False]
# Average Training RMSE :  0.0897554306082
# Average Test RMSE :  19829907972.6
# ##############################
# Encoding :  [True, True, False, False, True]
# Average Training RMSE :  0.0897537525147
# Average Test RMSE :  23757490461.4
# ##############################
# Encoding :  [True, False, True, True, False]
# Average Training RMSE :  0.0899462755584
# Average Test RMSE :  13515645878.3
# ##############################
# Encoding :  [True, False, True, False, True]
# Average Training RMSE :  0.0899450153483
# Average Test RMSE :  24867630984.2
# ##############################
# Encoding :  [True, False, False, True, True]
# Average Training RMSE :  0.0913372282528
# Average Test RMSE :  26620007470.6
# ##############################
# Encoding :  [False, True, True, True, False]
# Average Training RMSE :  0.088340203219
# Average Test RMSE :  0.0885078001124
# ##############################
# Encoding :  [False, True, True, False, True]
# Average Training RMSE :  0.0883380479166
# Average Test RMSE :  0.0885064915829
# ##############################
# Encoding :  [False, True, False, True, True]
# Average Training RMSE :  0.089755706108
# Average Test RMSE :  0.0899182780048
# ##############################
# Encoding :  [False, False, True, True, True]
# Average Training RMSE :  0.08994912226
# Average Test RMSE :  0.0901232818935
# ##############################
# Encoding :  [True, True, True, True, False]
# Average Training RMSE :  0.0883383047029
# Average Test RMSE :  16236872626.1
# ##############################
# Encoding :  [True, True, True, False, True]
# Average Training RMSE :  0.0883445618532
# Average Test RMSE :  173837943289.0
# ##############################
# Encoding :  [True, True, False, True, True]
# Average Training RMSE :  0.0897541104257
# Average Test RMSE :  20123477975.8
# ##############################
# Encoding :  [True, False, True, True, True]
# Average Training RMSE :  0.0899566385938
# Average Test RMSE :  94901418313.2
# ##############################
# Encoding :  [False, True, True, True, True]
# Average Training RMSE :  0.0883388212318
# Average Test RMSE :  0.088511062305
# ##############################
# Encoding :  [True, True, True, True, True]
# Average Training RMSE :  0.0884113908201
# Average Test RMSE :  1.33370191382e+12
# --------------------------------
# Best Combination :  [False, True, True, False, True]
# Combination Number :  23
# Training RMSE :  0.0883380479166
# Test RMSE :  0.0885064915829
# Coefficients :  [  4.50082784e+10   4.50082784e+10   4.50082784e+10   4.50082784e+10
#    4.50082784e+10   4.50082784e+10   4.50082784e+10   4.72867903e+09
#    4.72867903e+09   4.72867903e+09   4.72867903e+09   4.72867903e+09
#    4.72867903e+09  -4.34533516e+08  -4.34533516e+08  -4.34533516e+08
#   -4.34533516e+08  -4.34533516e+08  -4.34533516e+08  -3.80555631e+08
#   -3.80555631e+08  -3.80555631e+08  -3.80555631e+08  -3.80555631e+08
#   -3.80555631e+08  -3.26577746e+08  -3.26577746e+08  -3.26577746e+08
#   -3.26577746e+08  -3.26577746e+08  -3.26577746e+08  -2.72599861e+08
#   -2.72599861e+08  -2.72599861e+08  -2.72599861e+08  -2.72599861e+08
#   -2.72599861e+08  -2.18621977e+08  -2.18621977e+08  -2.18621977e+08
#   -2.18621977e+08  -2.18621977e+08  -2.18621977e+08  -6.00814819e-05
#   -5.39778848e+07]
# Intercept :  -49302423915.2

# %%
for i in range(0,32) :
    if ts_l[i] > 1:
        ts_l[i] = 1

# %%
plt.title("Training and Test RMSE for each combination")
plt.plot(range(1,33), tr_l, label="Training RMSE")
plt.plot(range(1,33), ts_l, color='red', label='Test RMSE')
plt.legend(loc = 'upper left')
plt.xlabel("Combinations")
plt.ylabel("Training and Test RMSE")
plt.show()

# %% [markdown]
# ### Part v

# %%
new_ridge = Ridge()
new_lasso = Lasso()
new_elasticnet = ElasticNet()

# %%
def partv(regressor,parameters):
    best_score = 10
    for i in range(1,32):
        print("##############################")
        print("Encoding : ",mask[i])
        encoder = OneHotEncoder(categorical_features = mask[i])
        X_encoded = encoder.fit_transform(X).toarray()
        clf = GridSearchCV(regressor, parameters, cv=10,scoring = 'neg_mean_squared_error')
        clf.fit(X_encoded,y)
        score = np.sqrt(-1 * clf.best_score_)
        print("Best Parameter : ",clf.best_params_)
        print("RMSE : ", score)
        if score < best_score:
            best_score = score
            best_param = clf.best_params_
            best_estimator = clf.best_estimator_
            best_mask = mask[i]
    print("---------------------------")
    print("Best Combination : ",best_mask)
    print("Parameter : ",best_param)
    print("Test RMSE : ",best_score)
    print("Coefficients : ",best_estimator.coef_)
    print("Intercept : ",best_estimator.intercept_)

# %%
parameters = {'alpha':[0.0001,0.001,0.1,1,10,100,1000,10000]}
partv(new_ridge,parameters)
# Out:
# ##############################
# Encoding :  [True, False, False, False, False]
# Best Parameter :  {'alpha': 10000}
# RMSE :  0.103673664218
# ##############################
# Encoding :  [False, True, False, False, False]
# Best Parameter :  {'alpha': 10}
# RMSE :  0.102231852837
# ##############################
# Encoding :  [False, False, True, False, False]
# Best Parameter :  {'alpha': 10}
# RMSE :  0.102465499369
# ##############################
# Encoding :  [False, False, False, True, False]
# Best Parameter :  {'alpha': 10}
# RMSE :  0.0914970533256
# ##############################
# Encoding :  [False, False, False, False, True]
# Best Parameter :  {'alpha': 1}
# RMSE :  0.0914984086895
# ##############################
# Encoding :  [True, True, False, False, False]
# Best Parameter :  {'alpha': 100}
# RMSE :  0.102242640467
# ##############################
# Encoding :  [True, False, True, False, False]
# Best Parameter :  {'alpha': 100}
# RMSE :  0.102551175986
# ##############################
# Encoding :  [True, False, False, True, False]
# Best Parameter :  {'alpha': 100}
# RMSE :  0.091587458889
# ##############################
# Encoding :  [True, False, False, False, True]
# Best Parameter :  {'alpha': 10}
# RMSE :  0.0916257948086
# ##############################
# Encoding :  [False, True, True, False, False]
# Best Parameter :  {'alpha': 10}
# RMSE :  0.101000281118
# ##############################
# Encoding :  [False, True, False, True, False]
# Best Parameter :  {'alpha': 10}
# RMSE :  0.0899065396966
# ##############################
# Encoding :  [False, True, False, False, True]
# Best Parameter :  {'alpha': 1}
# RMSE :  0.0899078982454
# ##############################
# Encoding :  [False, False, True, True, False]
# Best Parameter :  {'alpha': 10}
# RMSE :  0.0901236495225
# ##############################
# Encoding :  [False, False, True, False, True]
# Best Parameter :  {'alpha': 1}
# RMSE :  0.0901250391688
# ##############################
# Encoding :  [False, False, False, True, True]
# Best Parameter :  {'alpha': 10}
# RMSE :  0.0914981449718
# ##############################
# Encoding :  [True, True, True, False, False]
# Best Parameter :  {'alpha': 100}
# RMSE :  0.101012882124
# ##############################
# Encoding :  [True, True, False, True, False]
# Best Parameter :  {'alpha': 100}
# RMSE :  0.0899235386051
# ##############################
# Encoding :  [True, True, False, False, True]
# Best Parameter :  {'alpha': 10}
# RMSE :  0.0899386414402
# ##############################
# Encoding :  [True, False, True, True, False]
# Best Parameter :  {'alpha': 100}
# RMSE :  0.0902158424055
# ##############################
# Encoding :  [True, False, True, False, True]
# Best Parameter :  {'alpha': 10}
# RMSE :  0.0902613218117
# ##############################
# Encoding :  [True, False, False, True, True]
# Best Parameter :  {'alpha': 100}
# RMSE :  0.0915844182216
# ##############################
# Encoding :  [False, True, True, True, False]
# Best Parameter :  {'alpha': 10}
# RMSE :  0.0885040092843
# ##############################
# Encoding :  [False, True, True, False, True]
# Best Parameter :  {'alpha': 1}
# RMSE :  0.0885053878658
# ##############################
# Encoding :  [False, True, False, True, True]
# Best Parameter :  {'alpha': 10}
# RMSE :  0.0899076481742
# ##############################
# Encoding :  [False, False, True, True, True]
# Best Parameter :  {'alpha': 10}
# RMSE :  0.0901247541556
# ##############################
# Encoding :  [True, True, True, True, False]
# Best Parameter :  {'alpha': 100}
# RMSE :  0.0885231446107
# ##############################
# Encoding :  [True, True, True, False, True]
# Best Parameter :  {'alpha': 10}
# RMSE :  0.0885456845641
# ##############################
# Encoding :  [True, True, False, True, True]
# Best Parameter :  {'alpha': 100}
# RMSE :  0.0899204800161
# ##############################
# Encoding :  [True, False, True, True, True]
# Best Parameter :  {'alpha': 100}
# RMSE :  0.0902127341858
# ##############################
# Encoding :  [False, True, True, True, True]
# Best Parameter :  {'alpha': 10}
# RMSE :  0.0885051231976
# ##############################
# Encoding :  [True, True, True, True, True]
# Best Parameter :  {'alpha': 100}
# RMSE :  0.0885200104551
# ---------------------------
# Best Combination :  [False, True, True, True, False]
# Parameter :  {'alpha': 10}
# Test RMSE :  0.0885040092843
# Coefficients :  [  3.91627621e-02  -1.28132184e-02  -2.01924610e-02  -5.22906083e-03
#   -5.68395769e-03   3.26492675e-03   1.49100903e-03  -2.01413694e-02
#   -2.09906028e-02   7.76661954e-03   3.33486570e-02  -1.98564496e-03
#    2.00234054e-03   3.89679066e-02  -1.36046079e-02  -4.00945986e-02
#   -5.71782631e-02   7.19095630e-02   1.12276439e-05   7.06996262e-05]
# Intercept :  0.0597754701763

# %%
parameters = {'alpha':[0.0001,0.001,0.1,1,10,100,1000,10000]}
partv(new_lasso,parameters)
# Out:
# ##############################
# Encoding :  [True, False, False, False, False]
# Best Parameter :  {'alpha': 0.001}
# RMSE :  0.103671129332
# ##############################
# Encoding :  [False, True, False, False, False]
# Best Parameter :  {'alpha': 0.0001}
# RMSE :  0.102233153569
# ##############################
# Encoding :  [False, False, True, False, False]
# Best Parameter :  {'alpha': 0.0001}
# RMSE :  0.102467016538
# ##############################
# Encoding :  [False, False, False, True, False]
# Best Parameter :  {'alpha': 0.0001}
# RMSE :  0.0914981026218
# ##############################
# Encoding :  [False, False, False, False, True]
# Best Parameter :  {'alpha': 0.0001}
# RMSE :  0.0915321257068
# ##############################
# Encoding :  [True, True, False, False, False]
# Best Parameter :  {'alpha': 0.0001}
# RMSE :  0.102232343758
# ##############################
# Encoding :  [True, False, True, False, False]
# Best Parameter :  {'alpha': 0.0001}
# RMSE :  0.102494247758
# ##############################
# Encoding :  [True, False, False, True, False]
# Best Parameter :  {'alpha': 0.0001}
# RMSE :  0.0915211593896
# ##############################
# Encoding :  [True, False, False, False, True]
# Best Parameter :  {'alpha': 0.0001}
# RMSE :  0.0915557705191
# ##############################
# Encoding :  [False, True, True, False, False]
# Best Parameter :  {'alpha': 0.0001}
# RMSE :  0.101003330763
# ##############################
# Encoding :  [False, True, False, True, False]
# Best Parameter :  {'alpha': 0.0001}
# RMSE :  0.0899096268223
# ##############################
# Encoding :  [False, True, False, False, True]
# Best Parameter :  {'alpha': 0.0001}
# RMSE :  0.0899442791106
# ##############################
# Encoding :  [False, False, True, True, False]
# Best Parameter :  {'alpha': 0.0001}
# RMSE :  0.0901267187371
# ##############################
# Encoding :  [False, False, True, False, True]
# Best Parameter :  {'alpha': 0.0001}
# RMSE :  0.0901609601543
# ##############################
# Encoding :  [False, False, False, True, True]
# Best Parameter :  {'alpha': 0.0001}
# RMSE :  0.0914976673852
# ##############################
# Encoding :  [True, True, True, False, False]
# Best Parameter :  {'alpha': 0.0001}
# RMSE :  0.101002545316
# ##############################
# Encoding :  [True, True, False, True, False]
# Best Parameter :  {'alpha': 0.0001}
# RMSE :  0.0899088675582
# ##############################
# Encoding :  [True, True, False, False, True]
# Best Parameter :  {'alpha': 0.0001}
# RMSE :  0.0899435020743
# ##############################
# Encoding :  [True, False, True, True, False]
# Best Parameter :  {'alpha': 0.0001}
# RMSE :  0.0901485250867
# ##############################
# Encoding :  [True, False, True, False, True]
# Best Parameter :  {'alpha': 0.0001}
# RMSE :  0.0901833625418
# ##############################
# Encoding :  [True, False, False, True, True]
# Best Parameter :  {'alpha': 0.0001}
# RMSE :  0.0915207258373
# ##############################
# Encoding :  [False, True, True, True, False]
# Best Parameter :  {'alpha': 0.0001}
# RMSE :  0.0885094021684
# ##############################
# Encoding :  [False, True, True, False, True]
# Best Parameter :  {'alpha': 0.0001}
# RMSE :  0.088544404102
# ##############################
# Encoding :  [False, True, False, True, True]
# Best Parameter :  {'alpha': 0.0001}
# RMSE :  0.0899091683803
# ##############################
# Encoding :  [False, False, True, True, True]
# Best Parameter :  {'alpha': 0.0001}
# RMSE :  0.0901262755346
# ##############################
# Encoding :  [True, True, True, True, False]
# Best Parameter :  {'alpha': 0.0001}
# RMSE :  0.0885087077711
# ##############################
# Encoding :  [True, True, True, False, True]
# Best Parameter :  {'alpha': 0.0001}
# RMSE :  0.0885436922198
# ##############################
# Encoding :  [True, True, False, True, True]
# Best Parameter :  {'alpha': 0.0001}
# RMSE :  0.0899084089169
# ##############################
# Encoding :  [True, False, True, True, True]
# Best Parameter :  {'alpha': 0.0001}
# RMSE :  0.0901480839546
# ##############################
# Encoding :  [False, True, True, True, True]
# Best Parameter :  {'alpha': 0.0001}
# RMSE :  0.0885089569755
# ##############################
# Encoding :  [True, True, True, True, True]
# Best Parameter :  {'alpha': 0.0001}
# RMSE :  0.0885082624122
# ---------------------------
# Best Combination :  [True, True, True, True, True]
# Parameter :  {'alpha': 0.0001}
# Test RMSE :  0.0885082624122
# Coefficients :  [ -0.00000000e+00  -0.00000000e+00   0.00000000e+00  -0.00000000e+00
#    0.00000000e+00  -0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00  -0.00000000e+00   0.00000000e+00
#   -0.00000000e+00  -0.00000000e+00  -0.00000000e+00   4.37513766e-02
#   -6.96907942e-03  -1.44485670e-02  -0.00000000e+00  -0.00000000e+00
#    7.71880392e-03   5.93830959e-03  -2.10345963e-02  -2.18506978e-02
#    5.78177598e-03   3.14450311e-02  -2.79293029e-03   2.96261921e-06
#    5.17787530e-02  -0.00000000e+00  -2.56788220e-02  -4.23859230e-02
#    8.64849397e-02  -0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#   -0.00000000e+00   0.00000000e+00  -0.00000000e+00  -0.00000000e+00
#    0.00000000e+00  -0.00000000e+00  -0.00000000e+00  -0.00000000e+00
#   -0.00000000e+00   0.00000000e+00  -0.00000000e+00  -0.00000000e+00
#   -0.00000000e+00  -0.00000000e+00  -0.00000000e+00  -0.00000000e+00
#   -0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#   -0.00000000e+00   0.00000000e+00   0.00000000e+00]
# Intercept :  0.0431284722921

# %%
new_elasticnet = ElasticNet(max_iter = 10000)
parameters = {'alpha':[0.0001,0.001,0.1,1,10,100,1000,10000],'l1_ratio':[.1, .5, .7, .9, .95, .99, 1]}
partv(new_elasticnet,parameters)
# Out:
# ##############################
# Encoding :  [True, False, False, False, False]
# Best Parameter :  {'alpha': 0.001, 'l1_ratio': 0.5}
# RMSE :  0.103670353304
# ##############################
# Encoding :  [False, True, False, False, False]
# Best Parameter :  {'alpha': 0.0001, 'l1_ratio': 0.1}
# RMSE :  0.10223179185
# ##############################
# Encoding :  [False, False, True, False, False]
# Best Parameter :  {'alpha': 0.0001, 'l1_ratio': 0.1}
# RMSE :  0.102465502253
# ##############################
# Encoding :  [False, False, False, True, False]
# Best Parameter :  {'alpha': 0.0001, 'l1_ratio': 0.1}
# RMSE :  0.0914970673675
# ##############################
# Encoding :  [False, False, False, False, True]
# Best Parameter :  {'alpha': 0.0001, 'l1_ratio': 0.1}
# RMSE :  0.091498284852
# ##############################
# Encoding :  [True, True, False, False, False]
# Best Parameter :  {'alpha': 0.0001, 'l1_ratio': 0.7}
# RMSE :  0.102232032984
# ##############################
# Encoding :  [True, False, True, False, False]
# Best Parameter :  {'alpha': 0.001, 'l1_ratio': 0.1}
# RMSE :  0.102493882397
# ##############################
# Encoding :  [True, False, False, True, False]
# Best Parameter :  {'alpha': 0.001, 'l1_ratio': 0.1}
# RMSE :  0.0915195064478
# ##############################
# Encoding :  [True, False, False, False, True]
# Best Parameter :  {'alpha': 0.0001, 'l1_ratio': 0.99}
# RMSE :  0.0915557666355
# ##############################
# Encoding :  [False, True, True, False, False]
# Best Parameter :  {'alpha': 0.0001, 'l1_ratio': 0.1}
# RMSE :  0.101000229377
# ##############################
# Encoding :  [False, True, False, True, False]
# Best Parameter :  {'alpha': 0.0001, 'l1_ratio': 0.1}
# RMSE :  0.0899065485882
# ##############################
# Encoding :  [False, True, False, False, True]
# Best Parameter :  {'alpha': 0.0001, 'l1_ratio': 0.1}
# RMSE :  0.0899078066042
# ##############################
# Encoding :  [False, False, True, True, False]
# Best Parameter :  {'alpha': 0.0001, 'l1_ratio': 0.1}
# RMSE :  0.090123706818
# ##############################
# Encoding :  [False, False, True, False, True]
# Best Parameter :  {'alpha': 0.0001, 'l1_ratio': 0.1}
# RMSE :  0.0901248924712
# ##############################
# Encoding :  [False, False, False, True, True]
# Best Parameter :  {'alpha': 0.001, 'l1_ratio': 0.1}
# RMSE :  0.091497010609
# ##############################
# Encoding :  [True, True, True, False, False]
# Best Parameter :  {'alpha': 0.0001, 'l1_ratio': 0.5}
# RMSE :  0.101001170756
# ##############################
# Encoding :  [True, True, False, True, False]
# Best Parameter :  {'alpha': 0.0001, 'l1_ratio': 0.5}
# RMSE :  0.0899074175352
# ##############################
# Encoding :  [True, True, False, False, True]
# Best Parameter :  {'alpha': 0.0001, 'l1_ratio': 0.1}
# RMSE :  0.0899128808934
# ##############################
# Encoding :  [True, False, True, True, False]
# Best Parameter :  {'alpha': 0.001, 'l1_ratio': 0.1}
# RMSE :  0.0901476694032
# ##############################
# Encoding :  [True, False, True, False, True]
# Best Parameter :  {'alpha': 0.0001, 'l1_ratio': 0.95}
# RMSE :  0.090183176924
# ##############################
# Encoding :  [True, False, False, True, True]
# Best Parameter :  {'alpha': 0.001, 'l1_ratio': 0.1}
# RMSE :  0.0915193082978
# ##############################
# Encoding :  [False, True, True, True, False]
# Best Parameter :  {'alpha': 0.0001, 'l1_ratio': 0.1}
# RMSE :  0.0885041347576
# ##############################
# Encoding :  [False, True, True, False, True]
# Best Parameter :  {'alpha': 0.0001, 'l1_ratio': 0.1}
# RMSE :  0.0885053449722
# ##############################
# Encoding :  [False, True, False, True, True]
# Best Parameter :  {'alpha': 0.0001, 'l1_ratio': 0.1}
# RMSE :  0.0899070335508
# ##############################
# Encoding :  [False, False, True, True, True]
# Best Parameter :  {'alpha': 0.0001, 'l1_ratio': 0.1}
# RMSE :  0.0901241934421
# ##############################
# Encoding :  [True, True, True, True, False]
# Best Parameter :  {'alpha': 0.0001, 'l1_ratio': 0.5}
# RMSE :  0.0885056435854
# ##############################
# Encoding :  [True, True, True, False, True]
# Best Parameter :  {'alpha': 0.0001, 'l1_ratio': 0.1}
# RMSE :  0.0885096879776
# ##############################
# Encoding :  [True, True, False, True, True]
# Best Parameter :  {'alpha': 0.0001, 'l1_ratio': 0.7}
# RMSE :  0.0899072037973
# ##############################
# Encoding :  [True, False, True, True, True]
# Best Parameter :  {'alpha': 0.001, 'l1_ratio': 0.1}
# RMSE :  0.0901473370744
# ##############################
# Encoding :  [False, True, True, True, True]
# Best Parameter :  {'alpha': 0.0001, 'l1_ratio': 0.1}
# RMSE :  0.0885046231494
# ##############################
# Encoding :  [True, True, True, True, True]
# Best Parameter :  {'alpha': 0.0001, 'l1_ratio': 0.5}
# RMSE :  0.0885054667059
# ---------------------------
# Best Combination :  [False, True, True, True, False]
# Parameter :  {'alpha': 0.0001, 'l1_ratio': 0.1}
# Test RMSE :  0.0885041347576
# Coefficients :  [  4.44408782e-02  -7.55621693e-03  -1.49633759e-02  -0.00000000e+00
#   -4.10950189e-04   8.42870975e-03   6.64932445e-03  -2.07574009e-02
#   -2.16077887e-02   7.10663053e-03   3.27563959e-02  -2.54650999e-03
#    1.32681863e-03   5.24174310e-02  -0.00000000e+00  -2.63462105e-02
#   -4.32777307e-02   8.61851759e-02   1.06818909e-05   3.91963985e-05]
# Intercept :  0.0418354451908

# %% [markdown]
# <h2>Question 2 - b</h2>

# %%
dataset = pd.read_csv('network_backup_dataset.csv')
dataset['Day #'] = (dataset['Week #'] - 1) * 7 + encode_day_names(dataset['Day of Week'])

# %%
def encode_datalist(datalist):
    encoding = {}
    for i in datalist:
        if i in encoding:
            continue
        else:
            encoding[i] = i.split('_')[-1]
    return [encoding[i] for i in datalist]

# %%
dataset_copy = dataset.copy()

# %%
# dataset_copy contains scalar encoding of features
dataset_copy['Day of Week'] = encode_day_names(dataset_copy['Day of Week'])
dataset_copy['File Name'] = encode_datalist(dataset_copy['File Name'])
dataset_copy['Work-Flow-ID'] = encode_datalist(dataset_copy['Work-Flow-ID'])

# %%
dataset_copy.head()
# Out:
#    Week #  Day of Week  Backup Start Time - Hour of Day Work-Flow-ID  \
# 0       1            1                                1            0
# 1       1            1                                1            2
# 2       1            1                                1            2
# 3       1            1                                1            2
# 4       1            1                                1            2
#
#   File Name  Size of Backup (GB)  Backup Time (hour)  Day #
# 0         0                  0.0                   0      1
# 1        12                  0.0                   0      1
# 2        13                  0.0                   0      1
# 3        14                  0.0                   0      1
# 4        16                  0.0                   0      1

# %% [markdown]
# <h2>Part i</h2>

# %%
regr = RandomForestRegressor(n_estimators=20, max_depth=4, max_features=5, bootstrap=True, oob_score=True, random_state=0)
X = dataset_copy.iloc[:,:5].values
y = dataset_copy.iloc[:,5].values
train_rmse, test_rmse, best_rfr = perform_10fold(X, y, regr)
print("------------------------------")
print("Average Training RMSE : ",train_rmse)
print("Average Test RMSE : ",test_rmse)
# Out:
# Fold :  1
# Training RMSE :  0.0608127619351
# Test RMSE :  0.0619482244824
# Fold :  2
# Training RMSE :  0.0601612297879
# Test RMSE :  0.0596101321304
# Fold :  3
# Training RMSE :  0.0593906939253
# Test RMSE :  0.0732624795145
# Fold :  4
# Training RMSE :  0.0601581367598
# Test RMSE :  0.0523624583898
# Fold :  5
# Training RMSE :  0.0612088738697
# Test RMSE :  0.0584266811175
# Fold :  6
# Training RMSE :  0.0616024645485
# Test RMSE :  0.0533977390874
# Fold :  7
# Training RMSE :  0.0602120389363
# Test RMSE :  0.0661703601722
# Fold :  8
# Training RMSE :  0.0602323586423
# Test RMSE :  0.0670433518938
# Fold :  9
# Training RMSE :  0.0610613146866
# Test RMSE :  0.0597004806742
# Fold :  10
# Training RMSE :  0.0599592436311
# Test RMSE :  0.0524354241021
# ------------------------------
# Average Training RMSE :  0.0604832481886
# Average Test RMSE :  0.0607882493747

# %%
print("OOB Score: ", best_rfr.oob_score_)
print("OOB Error: ", 1-best_rfr.oob_score_)
# Out:
# OOB Score:  0.665390145054
# OOB Error:  0.334609854946

# %%
predicted = best_rfr.predict(X)

# %%
plot_graph(y,predicted,"Actual","Fitted","Fitted vs Actual")
plot_graph_time(y,predicted,"Actual","Fitted","Actual and Fitted values","Actual and Fitted values over time")
plot_graph(predicted,y-predicted,"Fitted","Residual","Residual vs Fitted")
plot_graph_time(y-predicted,predicted,"Residual","Fitted","Residual and Fitted values","Residual and Fitted values over time")

# %% [markdown]
# <h2>Part ii</h2>

# %%
def plot_func(x, oob, rmse, xlabel):
    print("Min OOB error at ",xlabel," : ", x[oob.index(min(oob))])
    print("Min RMSE at ",xlabel," : ", x[rmse.index(min(rmse))])
    plt.plot(x, oob, label="OOB Error")
    plt.plot(x, rmse, color='red', label='Test RMSE')
    plt.legend()
    plt.xlabel(xlabel)
    plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

trees = range(1,201)

for i in range(1,6):
    oob_errors = []
    test_rmse = []
    for t in trees:
        regr = RandomForestRegressor(n_estimators=t, max_depth=4, max_features=i, bootstrap=True, oob_score=True, random_state=0)
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=0)
        regr.fit(X_train, y_train)
        y_pred = regr.predict(X_test)
        oob_score = regr.oob_score_
        oob_error = 1 - oob_score
        oob_errors.append(oob_error)
        test_error = mean_squared_error(y_test,y_pred)
        test_rmse.append(np.sqrt(test_error))
    print("Max number of features: ",i)
    #plt.plot(trees, test_rmse)
    #plt.show()
    plot_func(trees, oob_errors, test_rmse, "# Trees")
# Out:
# Max number of features:  1
# Min OOB error at  # Trees  :  194
# Min RMSE at  # Trees  :  2
# Max number of features:  2
# Min OOB error at  # Trees  :  25
# Min RMSE at  # Trees  :  2
# Max number of features:  3
# Min OOB error at  # Trees  :  13
# Min RMSE at  # Trees  :  13
# Max number of features:  4
# Min OOB error at  # Trees  :  94
# Min RMSE at  # Trees  :  41
# Max number of features:  5
# Min OOB error at  # Trees  :  77
# Min RMSE at  # Trees  :  77

# %% [markdown]
# <h2>Part iii</h2>

# %%
depths = [1,2,3, 5,7,10,15,20, None]
for i in range(1,6):
    oob_errors = []
    test_rmse = []
    for d in depths:
        regr = RandomForestRegressor(n_estimators=13, max_depth=d, max_features=i, bootstrap=True, oob_score=True, random_state=0)
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=0)
        regr.fit(X_train, y_train)
        y_pred = regr.predict(X_test)
        oob_score = regr.oob_score_
        oob_error = 1 - oob_score
        oob_errors.append(oob_error)
        test_error = mean_squared_error(y_test,y_pred)
        test_rmse.append(np.sqrt(test_error))
    print("Max number of features: ",i)
    plot_func(depths, oob_errors, test_rmse, "Depths")
# Out:
# Max number of features:  1
# Min OOB error at  Depths  :  None
# Min RMSE at  Depths  :  20
# Max number of features:  2
# Min OOB error at  Depths  :  20
# Min RMSE at  Depths  :  20
# Max number of features:  3
# Min OOB error at  Depths  :  10
# Min RMSE at  Depths  :  10
# Max number of features:  4
# Min OOB error at  Depths  :  10
# Min RMSE at  Depths  :  10
# Max number of features:  5
# Min OOB error at  Depths  :  10
# Min RMSE at  Depths  :  10

# %% [markdown]
# <h2>Part iv</h2>

# %%
bestModel = RandomForestRegressor(n_estimators=13, max_depth=10, max_features=5, bootstrap=True, oob_score=True, random_state=0)
bestModel.fit(X,y)
print(bestModel.feature_importances_)
print(sorted(zip(map(lambda x: round(x, 4), bestModel.feature_importances_), dataset_copy.columns),
             reverse=True))
# Out:
# [ 0.00205728  0.19493121  0.39977323  0.15424762  0.24899066]
# [(0.39979999999999999, 'Backup Start Time - Hour of Day'), (0.249, 'File Name'), (0.19489999999999999, 'Day of Week'), (0.1542, 'Work-Flow-ID'), (0.0020999999999999999, 'Week #')]

# %%
predicted = bestModel.predict(X)

# %%
plot_graph(y,predicted,"Actual","Fitted","Fitted vs Actual")
plot_graph_time(y,predicted,"Actual","Fitted","Actual and Fitted values","Actual and Fitted values over time")
plot_graph(predicted,y-predicted,"Fitted","Residual","Residual vs Fitted")
plot_graph_time(y-predicted,predicted,"Residual","Fitted","Residual and Fitted values","Residual and Fitted values over time")

# %% [markdown]
# <h2>Part v</h2>

# %%
def plot_bar(importances, indices, features):
    plt.title('Feature Importances')
    plt.barh(range(len(indices)), importances[indices], color='b', align='center')
    plt.yticks(range(len(indices)), features[indices])
    plt.xlabel('Relative Importance')
    plt.show()

# %%
print("Visualizing feature importance for best model in Part iv")
bestModel = RandomForestRegressor(n_estimators=13, max_depth=10, max_features=5, bootstrap=True, oob_score=True, random_state=0)
bestModel.fit(X,y)
features = dataset_copy.columns[0:5]
importances = bestModel.feature_importances_
indices = np.argsort(importances)
plot_bar(importances, indices, features)
# Out:
# Visualizing feature importance for best model in Part iv

# %%
clf = bestModel.estimators_[3]
print("Visualizing feature importance for random forrest estimator with depth restricted to 4")
bestModel = RandomForestRegressor(n_estimators=13, max_depth=4, max_features=5, bootstrap=True, oob_score=True, random_state=0)
bestModel.fit(X,y)
clf = bestModel.estimators_[3]
features = dataset_copy.columns[0:5]
importances = clf.feature_importances_
indices = np.argsort(importances)
plot_bar(importances, indices, features)
# Out:
# Visualizing feature importance for random forrest estimator with depth restricted to 4

# %%
print("Visualizing decision tree for random forrest estimator with depth restricted to 4")
dot_data = tree.export_graphviz(clf, out_file=None, 
                         feature_names=features,   
                         filled=True, rounded=True,  
                         special_characters=True)
graph = graphviz.Source(dot_data) 
graph
# Out:
# Visualizing decision tree for random forrest estimator with depth restricted to 4
